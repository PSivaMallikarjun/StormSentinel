# %% [markdown]
# <a href="https://colab.research.google.com/github/PSivaMallikarjun/StormSentinel/blob/main/AI_Hurricane_Prediction_Web_App.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # AI Hurricane Prediction Web App

# %%
# !pip install gradio transformers torch numpy pandas matplotlib huggingface_hub geopy twilio folium
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.5/46.5 MB 12.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.2/322.2 kB 10.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 18.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 19.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 27.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 9.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 34.0 MB/s eta 0:00:00
# ...

# %% [markdown]
# # **Detailed Project Report (DPR)**
# ## **Project Title: AeroStorm AI – AI-driven Hurricane Prediction & Cloud Seeding System**
#
# ## **1. Executive Summary**
# ### **1.1 Project Overview**
# AeroStorm AI is an innovative AI-driven system designed to predict atmospheric pressure currents, forecast weather patterns, and utilize cloud seeding technology to dilute wind pressure and mitigate hurricanes. The system employs machine learning, real-time meteorological data analysis, and drone-based cloud seeding interventions to prevent or minimize hurricane impact.
#
# ### **1.2 Objectives**
# - To accurately predict **high and low-pressure currents** in the atmosphere.
# - To **forecast extreme weather events**, including hurricanes.
# - To deploy **cloud seeding drones** to dilute wind pressure and reduce hurricane intensity.
# - To provide **real-time alerts** to Geographic Information System (GIS) areas, weather governance portals, and research centers.
# - To develop an AI-powered **web application** for monitoring, forecasting, and mitigation.
#
# ## **2. Project Background & Justification**
# ### **2.1 Problem Statement**
# Hurricanes and extreme storms cause **catastrophic damage** to infrastructure, ecosystems, and human lives. Traditional forecasting methods lack precision and do not offer preventive solutions. There is a need for an **AI-driven system** that not only predicts hurricanes but also intervenes through **cloud seeding technology**.
#
# ### **2.2 Innovation & Uniqueness**
# AeroStorm AI is unique because it:
# - Uses **AI-driven atmospheric pressure semantics** for accurate predictions.
# - Integrates **real-time weather data, satellite imagery, and IoT sensors**.
# - Employs **drones for cloud seeding** to disrupt hurricane formation.
# - Sends **automated SMS alerts** to GIS areas and stakeholders.
#
# ## **3. Scope of Work**
# ### **3.1 System Components**
# 1. **Data Collection Module**: Gathers real-time meteorological data from satellites, IoT weather stations, and historical databases.
# 2. **AI Prediction Model**: Uses deep learning algorithms to predict hurricane formation and intensity.
# 3. **Cloud Seeding System**: Deploys AI-controlled drones to disperse cloud-seeding agents.
# 4. **Alert & Monitoring System**: Sends real-time alerts to stakeholders via SMS and web dashboard.
# 5. **User Interface (Web & Mobile App)**: Interactive dashboard for forecasting, alerting, and mitigation control.
#
# ## **4. Technology Stack**
# ### **4.1 AI & Machine Learning**
# - **Model:** Deep Learning (Transformers, LSTMs, GANs for atmospheric prediction)
# - **Frameworks:** TensorFlow, PyTorch, Scikit-learn
# - **Data Sources:** NOAA, NASA Satellite Data, IoT Sensors
#
# ### **4.2 Cloud Seeding & Drone Control**
# - **Drones:** AI-guided UAVs with automated deployment.
# - **Cloud Seeding Agents:** Silver Iodide (AgI), Dry Ice, Salt Particles.
# - **Deployment Strategy:** GPS-guided dynamic seeding patterns.
#
# ### **4.3 Web Application**
# - **Frontend:** React.js, Gradio (for AI models UI)
# - **Backend:** Python (Flask, FastAPI), Node.js
# - **Database:** PostgreSQL, MongoDB (Real-time weather logs)
# - **Deployment:** Google Colab, Hugging Face, AWS/GCP
#
# ### **4.4 Alert System**
# - **Communication:** Twilio API (SMS & Voice Alerts)
# - **GIS Mapping:** Folium, Google Maps API
#
# ## **5. Implementation Plan**
# ### **5.1 Development Phases**
# | Phase | Tasks | Timeline |
# |--------|-------------------------------------------------|------------|
# | **Phase 1** | Data collection, model training | 2 Months |
# | **Phase 2** | AI integration, cloud seeding drone prototype | 3 Months |
# | **Phase 3** | Web application development, GIS mapping | 2 Months |
# | **Phase 4** | Testing & Optimization | 1 Month |
# | **Phase 5** | Deployment & Scaling | 1 Month |
#
# ### **5.2 Team Structure**
# - **AI Engineers:** Develop predictive models & cloud seeding control algorithms.
# - **Meteorologists:** Validate weather prediction accuracy.
# - **Software Developers:** Build the web application & GIS dashboard.
# - **Drone Engineers:** Develop automated cloud-seeding drones.
# - **Data Scientists:** Analyze atmospheric data for precision forecasting.
#
# ## **6. Expected Impact**
# ### **6.1 Disaster Mitigation**
# - **Early hurricane warning** reduces loss of life & property damage.
# - **AI cloud seeding** could prevent hurricane intensification.
# - **GIS alerts** provide real-time disaster preparedness strategies.
#
# ### **6.2 Economic Benefits**
# - Reduces **economic losses** from hurricane damage.
# - Lowers **insurance claims** & recovery costs.
# - Improves **weather-dependent industries** (aviation, agriculture).
#
# ## **7. Budget & Funding**
# ### **7.1 Estimated Budget**
# | Item | Cost (USD) |
# |-----------------------------|------------|
# | AI Model Development | $50,000 |
# | Cloud Seeding Drone R&D | $100,000 |
# | Web & Mobile Application | $40,000 |
# | Weather Data Acquisition | $30,000 |
# | GIS & Alert System | $20,000 |
# | Testing & Deployment | $25,000 |
# | **Total Estimated Cost** | **$265,000** |
#
# ### **7.2 Funding Sources**
# - **Government Grants:** Meteorological & disaster prevention funding.
# - **Private Investment:** Tech startups & research institutions.
# - **Corporate Sponsorships:** Companies in climate & sustainability sectors.
# - **Crowdfunding:** Public contributions for climate tech initiatives.
#
# ## **8. Risk Analysis & Mitigation**
# ### **8.1 Key Risks & Countermeasures**
# | Risk | Probability | Impact | Mitigation Strategy |
# |----------------------|------------|-----------|------------------------------|
# | AI Model Inaccuracy | Medium | High | Improve dataset quality & ML tuning |
# | Drone Malfunction | Low | High | Implement redundant safety measures |
# | Regulatory Issues | Medium | Medium | Partner with government agencies |
# | Data Latency | High | Medium | Optimize cloud computing pipelines |
#
# ## **9. Conclusion & Future Scope**
# AeroStorm AI is a **game-changing innovation** in hurricane prediction and prevention. By leveraging AI-driven atmospheric analysis, **real-time alerts, and drone-based interventions**, this system has the potential to **save lives and reduce economic damage** caused by hurricanes.
#
# ### **Future Enhancements**
# - **Integration with IoT weather buoys** for improved sea-based forecasting.
# - **Enhancing AI models with quantum computing** for faster predictions.
# - **Automated UAV swarm technology** for large-scale cloud seeding operations.
#
# ## **10. References**
# - NOAA (National Oceanic and Atmospheric Administration)
# - NASA Climate & Weather Data Resources
# - Twilio SMS API for Disaster Alerts
# - Google Maps & Folium for GIS Integration
#
# ---
# ### **Prepared by:**
# Siva Mallikarjun Parvatham
# (Project Innovator – AeroStorm AI)

# %%
# Install required packages

import gradio as gr
import torch
from transformers import pipeline
import folium
from geopy.geocoders import Nominatim
from twilio.rest import Client

# Load AI Model (Example: Hugging Face Pre-trained Model)
model = pipeline("text-classification", model="distilbert-base-uncased")

# AI Function for Hurricane Prediction
def predict_hurricane(air_pressure, wind_speed, humidity):
    risk = (wind_speed * 0.5 + humidity * 0.3 + air_pressure * 0.2) / 100
    prediction = "High Risk" if risk > 0.6 else "Low Risk"

    return f"Hurricane Risk: {prediction} ({round(risk * 100, 2)}%)"

# Function for GIS Alert System
def send_alert(location):
    # Twilio setup (Replace with your credentials)
    account_sid = "your_account_sid"
    auth_token = "your_auth_token"
    client = Client(account_sid, auth_token)

    message = client.messages.create(
        body=f"⚠️ Hurricane Alert in {location}! Take necessary precautions.",
        from_="+1234567890", to="+9876543210"
    )
    return f"Alert sent to {location}!"

# Map Generator (Visualizing Affected Areas)
def generate_map(location):
    geolocator = Nominatim(user_agent="geoapi")
    loc = geolocator.geocode(location)

    map_ = folium.Map(location=[loc.latitude, loc.longitude], zoom_start=6)
    folium.Marker([loc.latitude, loc.longitude], tooltip="Hurricane Alert 🚨").add_to(map_)

    return map_._repr_html_()

# Gradio UI
with gr.Blocks() as app:
    gr.Markdown("# 🌪 AI Hurricane Prediction & Alert System")

    with gr.Row():
        air_pressure = gr.Number(label="Air Pressure (hPa)")
        wind_speed = gr.Number(label="Wind Speed (km/h)")
        humidity = gr.Number(label="Humidity (%)")

    predict_btn = gr.Button("Predict Hurricane Risk")
    result = gr.Textbox(label="Prediction Result")

    predict_btn.click(predict_hurricane, inputs=[air_pressure, wind_speed, humidity], outputs=result)

    gr.Markdown("### 📍 GIS Alert System")
    location = gr.Textbox(label="Enter Location")
    alert_btn = gr.Button("Send Alert")
    alert_result = gr.Textbox(label="Alert Status")

    alert_btn.click(send_alert, inputs=location, outputs=alert_result)

    gr.Markdown("### 🗺️ Map of Affected Area")
    map_btn = gr.Button("Generate Map")
    map_output = gr.HTML()

    map_btn.click(generate_map, inputs=location, outputs=map_output)

app.launch(share=True)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/483 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# ...

# %% [markdown]
# *   Altough it is Innovative but still needs development and igonore the alert error we didn't add the sensitive info. of global entites for obeying the rules of development ISO standards

# %% [markdown]
# # AI-Driven Hurricane Prediction & Cloud Seeding System
#
# ## Overview
# This project aims to predict lower and high-pressure currents in the atmosphere, forecast weather patterns, and utilize AI-driven cloud seeding to mitigate hurricane occurrences. The system leverages Air-Pressure Semantics and GIS-based alerts to provide early warnings and implement storm dilution techniques through drone-based cloud seeding.
#
# ## Innovation & Development Needs
# This AI-driven system is highly **innovative** but requires further **development** in the following key areas:
#
# ✅ **AI Model Accuracy** – Needs high-precision atmospheric data modeling.
# ✅ **Cloud Seeding Feasibility** – Requires real-world testing & regulatory approvals.
# ✅ **Ethical & Legal Compliance** – Must follow ISO, WMO, and environmental laws.
# ✅ **Real-time GIS Alerts** – Needs strong cybersecurity & data protection mechanisms.
#
# ## Compliance with ISO Standards
# Ignoring **global entity-sensitive information** ensures compliance with **ISO standards** and other regulatory guidelines. However, this approach has both **pros and cons**:
#
# ✔ **Right:** If the project is in the **development phase**, excluding **sensitive global climate & defense data** aligns with **ethical AI** and **ISO standards**.
#
# ❌ **Wrong:** If the system eventually requires **real-time international coordination** (e.g., NASA, NOAA, WMO, ISRO), lack of **proper protocols and data sources** may create regulatory and operational challenges during deployment.
#
# ## Conclusion
# This project is **innovative** but requires structured development, compliance measures, and feasibility studies before full-scale deployment. While early-stage development may not include **sensitive information**, integration with verified global data sources and governance approvals will be necessary for **real-world implementation**.
#
# ---
# 🚀 *Future Work: Further research on cloud seeding AI integration with drone-based atmospheric interventions!*

# %% [markdown]
# ![Screenshot 2025-04-03 221131.png](data:image/png;base64,...)![Screenshot 2025-04-03 221118.png](data:image/png;base64,...)![Screenshot 2025-04-03 221105.png](data:image/png;base64,...)![Screenshot 2025-04-03 221028.png](data:image/png;base64,...)
